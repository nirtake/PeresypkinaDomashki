# %% [markdown]
# #### Задача 1 (2 балла).
#
# Реализуйте с помощью классов базу данных для ветеринарного магазина из предыдущего семинара. Видимо, нам понадобятся два класса: для владельцев животных и для самих животных. У владельца мы храним имя, фамилию и номер телефона. У животного пусть будет кличка, возраст и дополнительный атрибут "записан на прием", в котором будет храниться информация о дате следующего приема (если ее нет - None). База данных должна храниться в бинарном файле (используйте pickle или dill). При запуске программы должны быть доступны несколько действий: завести нового клиента, завести новое животное для существующего клиента и записать животное на прием (или отметить, что прием прошел и новой записи нет). Сами экземпляры клиентов хранятся просто в списке.
#
# Примечание: в атрибутах могут храниться не только строки, но и списки, но не забывайте об их особенностях.

# %%
# your code here

# %% [markdown]
# #### Задача 2.
#
# Смоделируйте сценарий заказа еды в макдаке, определив четыре класса:
#
# **Lunch** - класс, который управляет всем событием \
# **Customer** - человек, который покупает блюдо \
# **Employee** - продавец \
# **Food** - сама еда
#
# Какие у них должны быть методы:
#
#     class Lunch:
#         def __init__(self) - создает экземпляры покупателя и продавца
#         def order(self, foodName) - начинает процесс заказа продавцом
#         def result(self) - запрашивает у покупателя, какой у него экземпляр еды
#
#     class Customer:
#         def __init__(self) инициирует еду у покупателя значением None (у покупателя сперва нет еды, он ее еще не купил)
#         def placeOrder(self, foodName, employee) - размещает заказ с экземпляром продавца, который обслуживает
#         def printFood(self)  выводит название блюда
#
#     class Employee:
#         def takeOrder(self, foodName) - возвращает экземпляр еды с запрошенным названием
#
#     class Food:
#     def __init__(self, name) - сохраняет название блюда
#
# Что должно происходить?
# 1. Конструктор класса Lunch заводит экземпляр покупателя и продавца, после чего метод order запрашивает у покупателя заказ, вызывая его метод placeOrder. В свою очередь placeOrder должен запрашивать у продавца новый объект Food, вызывая метод takeOrder.
# 2. Объект Food должен хранить строку с названием блюда, переданную из Lunch.order() методу Customer.placeOrder(), методу Employee.takeOrder() и, наконец, конструктору Food. Наконец класс Lunch запрашивает о результате, который должен вывести, какую еду получил наш покупатель.

# %%
# your code here

# %% [markdown]
# #### Задача 3 (2 балла).
#
# Напишите игрушку "Тамагочи". У вас должно быть минимум три класса: два для питомцев, один для самой игры. При начале игры игрок должен выбирать, какое животное он хочет завести, и давать ему имя. Возраст и другие характеристики животного можно генерировать случайным образом. Животное можно кормить и играть с ним, еще оно спит. Сама игра должна проходить в цикле, на каждой итерации можно проверять, хочет ли животное спать, и отправлять его, все потребности можно реализовать через динамические атрибуты. Если животное долго не кормить, оно умирает. (Атрибуты можно обновлять на каждой итерации)

# %%
from time import sleep
import random

class Pet:
    def __init__(self, animal, name):
        self.animal = animal
        self.name = name 
        self.skills = []
        self.yellow_hunger = 0
        self.red_hunger = -10
        self.yellow_tiredom = 2
        self.red_tiredom = -5
        if self.animal == 'an owl':
            self.age = random.randint(1, 15)
            self.sounds = ['Hoo-hoo', 'Who!']
            self.food = ['a mouse', 'a little bird', 'a frog']
            self.hello = ["Greetings and felicitations!", "Good day to you!"]
            self.hunger = 1
            self.tiredom = 2
            self.n = 2
            self.k = 3
        elif self.animal == 'an capibara':
            self.age = random.randint(1, 10)
            self.sounds = ['arf-arf', 'errrt']
            self.food = ['grass', 'a pumpkin', 'reed']
            self.hello = ["Hey, how's it going?", "What's up!"]
            self.hunger = 7
            self.tiredom = 6
            self.n = 3
            self.k = 4
        elif self.animal == 'a snake':
            self.age = random.randint(1, 25)
            self.sounds = ['Ssssss', 'Trrrrrr']
            self.food = ['a mouse', 'a rabbit', "an ostrich's egg"]
            self.hello = ["Long time no ssssee.", "Ssssalutations!"]
            self.hunger = 9
            self.tiredom = 3
            self.n = 2
            self.k = 2
        elif self.animal == 'a raven':
            self.hunger = 3
            self.tiredom = 5
            self.n = 5
            self.k = 1
            self.sounds = ['Carrr', 'Crack-crack']
            self.hello = ["Heil!", "Good day!", "What Do Ye!"]   
            if self.name.lower() == 'nevermore':
                self.age = random.randint(100, 300)
                self.food = ["a sinner's soul", "a dead maiden"]
            else:
                self.age = random.randint(1, 10)
                self.food = ['offal', 'a worm']
        else:
            print('Choose an animal from the list') 
        
    def __str__(self):
        return f"Hi, my name is {self.name} and I'm {self.animal} and I'm {self.age} y.o."
     
    def feed(self):
        m = self.food[random.randint(0, len(self.food))]
        self.hunger += self.n * (len(m) / 2)
        return print(f"{self.name} is eating {m}")
    
    def sleeping(self, hours):
        self.hours = int(hours)
        self.tiredom += self.k * self.hours
        sleep(self.hours)
        return print(f"{self.name()} has slept and can now play with you")
    
    def play(self):
        print(f"Guess the number! You have 10 tries. {self.sounds[random.randint(0, len(self.sounds))]}")
        x = random.randint(1, 1024)
        y = int(input())
        i = 0
        while i < 10:
            if 0 < y < 1024 and y != x:
                if y > x:
                    print('Your number is too big')
                if y < x:
                    print('Your number is too small')
                i += 1 
                y = int(input())
            if x == y:
                print('You won!')
                break
            if y < 1 or y > 1023:
                print('Choose a number between 0 and 1023')
                i += 0
                y = int(input())
        print(f'You lost, the right number was {x}')
        self.hunger -= 3
        self.tiredom -= 5
    
    def teach(self, skill):
        if self.tiredom() - (len(skill) * 2) >= 0 and self.hunger() - len(skill) >= 0:
            sleep(len(skill))
            self.skills.append(skill)
            self.tiredom -= (len(skill) * 2)
            self.hunger -= len(skill)
            print(f"Now I've got a new skill: {skill}! {self.sounds[random.randint(0, len(self.sounds))]}")
        else: 
            print("I'm too tired for getting this skill:(")

    def say_hello(self):
        print(f"{self.hello[random.randint(0, len(self.hello))]} {self.sounds[random.randint(0, len(self.sounds))]}")
        

            
class Game:
    def __init__(self):
      self.yellow_hunger = 0
      self.red_hunger = -10
      self.yellow_tiredom = 2
      self.red_tiredom = -5
    def play(self):
        self.pet = Pet(input("Choose an animal: an owl, a capibara, a snake or a raven"), input("Choose a name for your pet"))
        print(self.pet)
        while self.pet.hunger > self.red_hunger and self.pet.tiredom > self.red_tiredom:
            action = input("Choose what you whant to do with your pet (feed, get to sleep, play, teach a new skill, say hello)")
            if action == "feed":
                self.pet.feed()
            elif action == "get to sleep":
                h = input("How long do you want your pet to sleep? (put in a number)")
                self.pet.sleeping(h)
            elif action == "play":
                self.pet.play()
            elif action == "teach a new skill":
                self.pet.teach(input('what skill do ypu what to teach?'))
            elif action == "say hello":
                self.pet.say_hello()
            else:
                print("Please, choose an action from the list (feed, get to sleep, play, teach a new skill, say hello)")
                continue
            if self.pet.hunger <= self.yellow_hunger:
                print("I'm hungry, please feed me!")
            else:
                continue
            if self.pet.tiredom <= self.yellow_tiredom:
                print("I'm very tired, I need some sleep")
            else:
                continue
        print("Sorry, your pet has gone to the better world but you can try again and kill a new creature.")

      
#я не успела до конца проверить, как оно работает, там наверняка остлись ошибки, извините
